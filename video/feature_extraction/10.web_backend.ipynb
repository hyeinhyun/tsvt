# %%
key = '0TvQnueqKa5mxJntVWt0w4LpLfEkrV1Ta8rQBb9Z'

# %%
import requests
header = {'x-api-key':key}

leagues = 'https://esports-api.lolesports.com/persisted/gw/getLeagues?hl=ko-KR'
r = requests.get(leagues,headers = header)
data = r.json()
print(data)
dlist=[]
for i in data['data']['leagues']:
    dlist.append([[i['name']],i['id'],i['image']])
dlist
# Out:
# {'data': {'leagues': [{'id': '100695891328981122', 'slug': 'european-masters', 'name': 'European Masters', 'region': '유럽', 'image': 'http://static.lolesports.com/leagues/1585044513499_EM_BUG_2020%20(1).png', 'priority': 215}, {'id': '101097443346691685', 'slug': 'turkey-academy-league', 'name': 'TAL', 'region': '터키', 'image': 'http://static.lolesports.com/leagues/1592516072459_TAL-01-FullonDark.png', 'priority': 1000}, {'id': '101382741235120470', 'slug': 'lla', 'name': 'Liga Latinoamérica', 'region': '라틴 아메리카', 'image': 'http://static.lolesports.com/leagues/1592516315279_LLA-01-FullonDark.png', 'priority': 209}, {'id': '104366947889790212', 'slug': 'pcs', 'name': 'PCS', 'region': '홍콩, 마카오, 대만', 'image': 'http://static.lolesports.com/leagues/1592515942679_PCS-01-FullonDark.png', 'priority': 1000}, {'id': '98767975604431411', 'slug': 'worlds', 'name': '월드 챔피언십', 'region': '국제 대회', 'image': 'http://static.lolesports.com/leagues/1592594612171_WorldsDarkBG.png', 'priority': 0}, {'id': '98767991295297326', 'slug': 'all-star', 'name': '올스타전', 'region': '국제 대회', 'image': 'http://static.lolesports.com/leagues/1592594737227_ASEDarkBG.png', 'priority': 213}, {'id': '98767991299243165', 'slug': 'lcs', 'name': 'LCS', 'region': '북미', 'image': 'http://static.lolesports.com/leagues/1592516141735_LCS-01-FullonDark.png', 'priority': 203}, {'id': '98767991302996019', 'slug': 'lec', 'name': 'LEC', 'region': '유럽', 'image': 'http://static.lolesports.com/leagues/1592516184297_LEC-01-FullonDark.png', 'priority': 202}, {'id': '98767991310872058', 'slug': 'lck', 'name': 'LCK', 'region': '한국', 'image': 'http://static.lolesports.com/leagues/1592516205122_LCK-01-FullonDark.png', 'priority': 1}, {'id': '98767991314006698', 'slug': 'lpl', 'name': 'LPL', 'region': '중국', 'image': 'http://static.lolesports.com/leagues/1592516115322_LPL-01-FullonDark.png', 'priority': 201}, {'id': '98767991325878492', 'slug': 'msi', 'name': 'MSI', 'region': '국제 대회', 'image': 'http://static.lolesports.com/leagues/1592594634248_MSIDarkBG.png', 'priority': 212}, {'id': '98767991331560952', 'slug': 'oce-opl', 'name': 'OPL', 'region': '오세아니아', 'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/league/oce-opl-e0qfb3l8.png', 'priority': 210}, {'id': '98767991332355509', 'slug': 'cblol-brazil', 'name': 'CBLOL', 'region': '브라질', 'image': 'http://static.lolesports.com/leagues/1592516282648_CBLOL-01-FullonDark.png', 'priority': 208}, {'id': '98767991343597634', 'slug': 'turkiye-sampiyonluk-ligi', 'name': 'TCL', 'region': '터키', 'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/league/turkiye-sampiyonluk-ligi-8r9ofb9.png', 'priority': 207}, {'id': '98767991349978712', 'slug': 'ljl-japan', 'name': 'LJL', 'region': '일본', 'image': 'http://static.lolesports.com/leagues/1592516354053_LJL-01-FullonDark.png', 'priority': 206}, {'id': '99332500638116286', 'slug': 'lcs-academy', 'name': '북미 아카데미', 'region': '북미', 'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/league/lcs-academy-4o8goq8n.png', 'priority': 205}]}}
# [[['European Masters'],
#   '100695891328981122',
#   'http://static.lolesports.com/leagues/1585044513499_EM_BUG_2020%20(1).png'],
#  [['TAL'],
#   '101097443346691685',
#   'http://static.lolesports.com/leagues/1592516072459_TAL-01-FullonDark.png'],
#  [['Liga Latinoamérica'],
#   '101382741235120470',
#   'http://static.lolesports.com/leagues/1592516315279_LLA-01-FullonDark.png'],
#  [['PCS'],
#   '104366947889790212',
#   'http://static.lolesports.com/leagues/1592515942679_PCS-01-FullonDark.png'],
#  [['월드 챔피언십'],
#   '98767975604431411',
#   'http://static.lolesports.com/leagues/1592594612171_WorldsDarkBG.png'],
#  [['올스타전'],
#   '98767991295297326',
#   'http://static.lolesports.com/leagues/1592594737227_ASEDarkBG.png'],
#  [['LCS'],
#   '98767991299243165',
#   'http://static.lolesports.com/leagues/1592516141735_LCS-01-FullonDark.png'],
#  [['LEC'],
#   '98767991302996019',
#   'http://static.lolesports.com/leagues/1592516184297_LEC-01-FullonDark.png'],
#  [['LCK'],
#   '98767991310872058',
#   'http://static.lolesports.com/leagues/1592516205122_LCK-01-FullonDark.png'],
#  [['LPL'],
#   '98767991314006698',
#   'http://static.lolesports.com/leagues/1592516115322_LPL-01-FullonDark.png'],
#  [['MSI'],
#   '98767991325878492',
#   'http://static.lolesports.com/leagues/1592594634248_MSIDarkBG.png'],
#  [['OPL'],
#   '98767991331560952',
#   'https://lolstatic-a.akamaihd.net/esports-assets/production/league/oce-opl-e0qfb3l8.png'],
#  [['CBLOL'],
#   '98767991332355509',
#   'http://static.lolesports.com/leagues/1592516282648_CBLOL-01-FullonDark.png'],
#  [['TCL'],
#   '98767991343597634',
#   'https://lolstatic-a.akamaihd.net/esports-assets/production/league/turkiye-sampiyonluk-ligi-8r9ofb9.png'],
#  [['LJL'],
#   '98767991349978712',
#   'http://static.lolesports.com/leagues/1592516354053_LJL-01-FullonDark.png'],
#  [['북미 아카데미'],
#   '99332500638116286',
#   'https://lolstatic-a.akamaihd.net/esports-assets/production/league/lcs-academy-4o8goq8n.png']]

# %%
# 리그 선택
match_list_18 = []
header = {'x-api-key':key}
param = {'leagueId':98767975604431411}

leagues = 'https://esports-api.lolesports.com/persisted/gw/getTournamentsForLeague?hl=ko-KR'
r = requests.get(leagues,headers = header,params = param)
print(r.url)
print(r.headers)
data = r.json()
data
# Out:
# https://esports-api.lolesports.com/persisted/gw/getTournamentsForLeague?hl=ko-KR&leagueId=98767975604431411
# {'Content-Type': 'application/json', 'Content-Length': '225', 'Connection': 'keep-alive', 'Date': 'Sat, 07 Nov 2020 13:17:48 GMT', 'x-amzn-RequestId': '23d50183-043f-4ef2-9aa8-cb8162f851f2', 'Access-Control-Allow-Origin': '*', 'Content-Encoding': 'gzip', 'Access-Control-Allow-Headers': 'Content-Type,X-Api-Key', 'x-amz-apigw-id': 'Vo2zcFr7PHcFSRg=', 'Cache-Control': 'max-age=60', 'Access-Control-Allow-Methods': 'GET,OPTIONS', 'X-Amzn-Trace-Id': 'Root=1-5fa69e7c-06491cbb28b6fc24752ffea9', 'Via': '1.1 cf334f8d204150d702090aa22e0fab56.cloudfront.net (CloudFront), 1.1 c9175050329bc171442756cc6f0e0d88.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'HIO51-C1, HIO51-C1', 'X-Cache': 'Miss from cloudfront', 'X-Amz-Cf-Id': 'MB6Zd_mQXMKEfZHjmiJY1rH0zBODV_lHG4pYW97tEyZb2mEIO4Duow=='}
# {'data': {'leagues': [{'tournaments': [{'endDate': '2018-11-03',
#       'id': '100783238182986407',
#       'slug': 'world_championship_2018',
#       'startDate': '2018-10-01'},
#      {'endDate': '2019-11-10',
#       'id': '102804906674705057',
#       'slug': 'world_championship_2019',
#       'startDate': '2019-10-02'},
#      {'endDate': '2020-10-31',
#       'id': '104841804583318464',
#       'slug': 'worlds_2020',
#       'startDate': '2020-09-25'},
#      {'endDate': '2017-11-04',
#       'id': '98767991971246908',
#       'slug': 'world_championship_2017',
#       'startDate': '2017-09-22'}]}]}}

# %%
# 토너먼트 선택

#get events(all match in tournament)
header = {'x-api-key':key}
param = {'tournamentId':104841804583318464}

leagues = 'https://esports-api.lolesports.com/persisted/gw/getCompletedEvents?hl=ko-KR'
r = requests.get(leagues,headers = header,params = param)
data = r.json()

# %%
data['data']['schedule']['events']
# Out:
# [{'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413344',
#     'vods': [{'parameter': '6Pp9jEXMgLQ'},
#      {'parameter': 'meqdDNnqI_w'},
#      {'parameter': 'p5PBW0n9aOg'},
#      {'parameter': 'fsoW1OzbMH4'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413343',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'MAD',
#      'image': 'http://static.lolesports.com/teams/1592591395339_MadLionsMAD-01-FullonDark.png',
#      'name': 'MAD Lions',
#      'result': {'gameWins': 1}},
#     {'code': 'ITZ',
#      'image': 'http://static.lolesports.com/teams/INTZINTZ-01-FullonDark.png',
#      'name': 'INTZ',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-25T08:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413364',
#     'vods': [{'parameter': '18JfK-zX6Rs'},
#      {'parameter': 'bEs72l-jLc8'},
#      {'parameter': 'ULl5vjQ_rV8'},
#      {'parameter': 'f5zctMHxUao'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413363',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 1}},
#     {'code': 'R7',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/rainbow7-ir4dkg7.png',
#      'name': 'Rainbow7 ',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-25T09:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413348',
#     'vods': [{'parameter': 'knyhvk29gcA'},
#      {'parameter': 'xLXH2nlB_Ds'},
#      {'parameter': 'uwSNC7rm2jE'},
#      {'parameter': 'xvJa0F4Cbno'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413347',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'LGC',
#      'image': 'http://static.lolesports.com/teams/LegacyEsportsLGC-01-FullonDark.png',
#      'name': 'Legacy Esports',
#      'result': {'gameWins': 1}},
#     {'code': 'ITZ',
#      'image': 'http://static.lolesports.com/teams/INTZINTZ-01-FullonDark.png',
#      'name': 'INTZ',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-25T10:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413352',
#     'vods': [{'parameter': 'oRG-bNxWLNk'},
#      {'parameter': 'z-9cAjaM9W0'},
#      {'parameter': 'RQb07XSsuVE'},
#      {'parameter': 'k3XxMccGYws'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413351',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 0}},
#     {'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-25T11:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589151188',
#     'vods': [{'parameter': 'n9IqFktNXSI'},
#      {'parameter': 'qg8z5BFaz_0'},
#      {'parameter': 'gw5D-uHs9qo'},
#      {'parameter': 'k3XxMccGYws'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589085651',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 1}},
#     {'code': 'MAD',
#      'image': 'http://static.lolesports.com/teams/1592591395339_MadLionsMAD-01-FullonDark.png',
#      'name': 'MAD Lions',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-25T12:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413368',
#     'vods': [{'parameter': 'sgNGr67xdX8'},
#      {'parameter': 'w7x0lIcjKDE'},
#      {'parameter': 'Wt5b9VRPoCY'},
#      {'parameter': 'Df11J1P5tfQ'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413367',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'R7',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/rainbow7-ir4dkg7.png',
#      'name': 'Rainbow7 ',
#      'result': {'gameWins': 0}},
#     {'code': 'V3',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/v3-esports-4r8dffpi.png',
#      'name': 'V3 Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-26T08:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413350',
#     'vods': [{'parameter': '8TtTPwG1pC4'},
#      {'parameter': 'xmfLYyUHbZ0'},
#      {'parameter': 'iQGP6qCTpYA'},
#      {'parameter': 'ETiVO9UGBHo'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413349',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'ITZ',
#      'image': 'http://static.lolesports.com/teams/INTZINTZ-01-FullonDark.png',
#      'name': 'INTZ',
#      'result': {'gameWins': 0}},
#     {'code': 'SUP',
#      'image': 'http://static.lolesports.com/teams/1600193815727_SuperMassiveEsportsSUP-01-FullonDark.png',
#      'name': 'Papara SuperMassive',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-26T09:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413366',
#     'vods': [{'parameter': 'cSHrErwHUWw'},
#      {'parameter': 'EXZllOgUZVg'},
#      {'parameter': 'yql95wU99_Y'},
#      {'parameter': 'yCjnFPUfSds'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413365',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'V3',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/v3-esports-4r8dffpi.png',
#      'name': 'V3 Esports',
#      'result': {'gameWins': 0}},
#     {'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-26T10:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413358',
#     'vods': [{'parameter': '24OhAMJGkko'},
#      {'parameter': 'AUybHyaK8ts'},
#      {'parameter': 'NJ24OpQWB2M'},
#      {'parameter': 'GwcyRTxv-lU'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413357',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 0}},
#     {'code': 'R7',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/rainbow7-ir4dkg7.png',
#      'name': 'Rainbow7 ',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-26T11:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413362',
#     'vods': [{'parameter': 'z5rd9phofJo'},
#      {'parameter': 'kixcIsX1nPg'},
#      {'parameter': 're_7zeJxPJY'},
#      {'parameter': '2M2sKeZdY_A'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413361',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 1}},
#     {'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-26T12:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413342',
#     'vods': [{'parameter': 'jvNGqL6wftE'},
#      {'parameter': 'ME7YNmAQ-io'},
#      {'parameter': 'diSxDF2sO7o'},
#      {'parameter': 'us-ennt9H48'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413341',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'SUP',
#      'image': 'http://static.lolesports.com/teams/1600193815727_SuperMassiveEsportsSUP-01-FullonDark.png',
#      'name': 'Papara SuperMassive',
#      'result': {'gameWins': 1}},
#     {'code': 'MAD',
#      'image': 'http://static.lolesports.com/teams/1592591395339_MadLionsMAD-01-FullonDark.png',
#      'name': 'MAD Lions',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-26T13:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413334',
#     'vods': [{'parameter': 'Jh0wi0UIN3Y'},
#      {'parameter': 'mrWoqyb_zCk'},
#      {'parameter': 'HXFXT8eq4rU'},
#      {'parameter': 'PBmETcdf3N8'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413333',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 1}},
#     {'code': 'LGC',
#      'image': 'http://static.lolesports.com/teams/LegacyEsportsLGC-01-FullonDark.png',
#      'name': 'Legacy Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-26T14:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413354',
#     'vods': [{'parameter': 'f48RBJ_N6tw'},
#      {'parameter': 'YP0YHtPBoY8'},
#      {'parameter': 'w-GVzI4tf_4'},
#      {'parameter': 'ph3D4oQ5x-g'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413353',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'V3',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/v3-esports-4r8dffpi.png',
#      'name': 'V3 Esports',
#      'result': {'gameWins': 0}},
#     {'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-27T08:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413370',
#     'vods': [{'parameter': '-KsCvUiT2mw'},
#      {'parameter': 'AS_gEGhNRdQ'},
#      {'parameter': '5XjLay6qx1E'},
#      {'parameter': 'o99rs7Ea01w'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413369',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'R7',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/rainbow7-ir4dkg7.png',
#      'name': 'Rainbow7 ',
#      'result': {'gameWins': 1}},
#     {'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-27T09:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413360',
#     'vods': [{'parameter': 'xGfScTB1QXM'},
#      {'parameter': 'nizBU7WUXCM'},
#      {'parameter': 'zY2wAeUh3uY'},
#      {'parameter': 'C1T_ZQkqe_Q'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413359',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 1}},
#     {'code': 'V3',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/v3-esports-4r8dffpi.png',
#      'name': 'V3 Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-27T10:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413356',
#     'vods': [{'parameter': 'HhoZ-c3iTUc'},
#      {'parameter': '_Bh4YA4NBYg'},
#      {'parameter': 'FlUCBy8DbR4'},
#      {'parameter': '9BowMJwGg5w'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413355',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 1}},
#     {'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-27T11:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104936772876713568',
#     'vods': [{'parameter': '923zH47HfQc'},
#      {'parameter': '6TrtmNHdhZc'},
#      {'parameter': 'rJOnJuhfyAM'},
#      {'parameter': 'OX4zC6O20vk'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104936772876648031',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}},
#     {'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 1}}],
#    'type': 'tiebreaker'},
#   'startTime': '2020-09-27T12:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104936778827926888',
#     'vods': [{'parameter': 'MrTGKbI7XQY'},
#      {'parameter': '_bk8gPo48GA'},
#      {'parameter': '44a7XWfi9ng'},
#      {'parameter': '8RV2jt0tnlY'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104936778827861351',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 1}},
#     {'code': 'V3',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/v3-esports-4r8dffpi.png',
#      'name': 'V3 Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'tiebreaker'},
#   'startTime': '2020-09-27T13:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413336',
#     'vods': [{'parameter': 'pcALryw6ezQ'},
#      {'parameter': 'h4yUoBB3I0s'},
#      {'parameter': 'x0BTT3arnk4'},
#      {'parameter': 'UDWf0zu_thc'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413335',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'SUP',
#      'image': 'http://static.lolesports.com/teams/1600193815727_SuperMassiveEsportsSUP-01-FullonDark.png',
#      'name': 'Papara SuperMassive',
#      'result': {'gameWins': 0}},
#     {'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-28T08:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413340',
#     'vods': [{'parameter': 'Z8Xpm3lgI9Y'},
#      {'parameter': 'LOEfeHjYowY'},
#      {'parameter': 'XE-v9JRMRD8'},
#      {'parameter': 'gU3rlOP-9mc'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413339',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'MAD',
#      'image': 'http://static.lolesports.com/teams/1592591395339_MadLionsMAD-01-FullonDark.png',
#      'name': 'MAD Lions',
#      'result': {'gameWins': 0}},
#     {'code': 'LGC',
#      'image': 'http://static.lolesports.com/teams/LegacyEsportsLGC-01-FullonDark.png',
#      'name': 'Legacy Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-09-28T09:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413338',
#     'vods': [{'parameter': 'rjdtpVAyC40'},
#      {'parameter': 'vSvlmrThu1s'},
#      {'parameter': 'c8PUubj9ta0'},
#      {'parameter': 'xKV-f9ZivrQ'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413337',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'ITZ',
#      'image': 'http://static.lolesports.com/teams/INTZINTZ-01-FullonDark.png',
#      'name': 'INTZ',
#      'result': {'gameWins': 1}},
#     {'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-28T10:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104841804589413346',
#     'vods': [{'parameter': 'cArlaf6h0_s'},
#      {'parameter': 'ypNT93vsNYI'},
#      {'parameter': 'JmDeLdbgljY'},
#      {'parameter': 'Lg8l76wp8OA'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413345',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'LGC',
#      'image': 'http://static.lolesports.com/teams/LegacyEsportsLGC-01-FullonDark.png',
#      'name': 'Legacy Esports',
#      'result': {'gameWins': 1}},
#     {'code': 'SUP',
#      'image': 'http://static.lolesports.com/teams/1600193815727_SuperMassiveEsportsSUP-01-FullonDark.png',
#      'name': 'Papara SuperMassive',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-28T11:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104942192322039819',
#     'vods': [{'parameter': 'zo-Rbv-40bc'},
#      {'parameter': 'k_FWiJeUK7w'},
#      {'parameter': 'wvHsUulnHbg'},
#      {'parameter': 'nB8SpAdymkw'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104942192321974282',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'MAD',
#      'image': 'http://static.lolesports.com/teams/1592591395339_MadLionsMAD-01-FullonDark.png',
#      'name': 'MAD Lions',
#      'result': {'gameWins': 1}},
#     {'code': 'ITZ',
#      'image': 'http://static.lolesports.com/teams/INTZINTZ-01-FullonDark.png',
#      'name': 'INTZ',
#      'result': {'gameWins': 0}}],
#    'type': 'tiebreaker'},
#   'startTime': '2020-09-28T12:00:00Z'},
#  {'blockName': '플레이-인 그룹 스테이지',
#   'games': [{'id': '104942405977919501',
#     'vods': [{'parameter': 'Lbh0GrWt8ko'},
#      {'parameter': 'ZPsSyFX-CJM'},
#      {'parameter': 'SNci_3mLSyI'},
#      {'parameter': '2iC9Vi8DPVc'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104942405977919500',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 1}},
#     {'code': 'LGC',
#      'image': 'http://static.lolesports.com/teams/LegacyEsportsLGC-01-FullonDark.png',
#      'name': 'Legacy Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'tiebreaker'},
#   'startTime': '2020-09-28T13:00:00Z'},
#  {'blockName': '플레이-인 토너먼트 스테이지',
#   'games': [{'id': '104841804589413378',
#     'vods': [{'parameter': 'Pit4zFNuDyw'},
#      {'parameter': 'QvBxx98Vg6k'},
#      {'parameter': 'qU98DgaSGVo'},
#      {'parameter': 'b0g16Cg__FU'}]},
#    {'id': '104841804589413379',
#     'vods': [{'parameter': 'cPtATuuTDcI'},
#      {'parameter': 'LsPJc52fSoY'},
#      {'parameter': 'XO7XxyeiiEs'},
#      {'parameter': 'NgGGhsBQfq0'}]},
#    {'id': '104841804589478916',
#     'vods': [{'parameter': 'zY507a9r4tI'},
#      {'parameter': 'v2hmCXM-SZY'},
#      {'parameter': '5vPylGEEDK0'},
#      {'parameter': 'n_9kGJ4j7Ec'}]},
#    {'id': '104841804589478917', 'vods': []},
#    {'id': '104841804589478918', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413377',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'R7',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/rainbow7-ir4dkg7.png',
#      'name': 'Rainbow7 ',
#      'result': {'gameWins': 0}},
#     {'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 3}}],
#    'type': 'normal'},
#   'startTime': '2020-09-29T06:00:00Z'},
#  {'blockName': '플레이-인 토너먼트 스테이지',
#   'games': [{'id': '104841804589413372',
#     'vods': [{'parameter': '2j3VOVW5kro'},
#      {'parameter': 'vja3pasLT-M'},
#      {'parameter': 'GT8lGkJVjLA'},
#      {'parameter': 'inqL5HCyJsw'}]},
#    {'id': '104841804589413373',
#     'vods': [{'parameter': '2eFPM2ib_Jg'},
#      {'parameter': 'zo49tg8XiRg'},
#      {'parameter': '3aHQy1KOVLI'},
#      {'parameter': 'NM5y0wuD6CY'}]},
#    {'id': '104841804589413374',
#     'vods': [{'parameter': 'pjLWeE1iyM8'},
#      {'parameter': 'NyEKiiiur5Y'},
#      {'parameter': 'k9_VxJu7sgM'},
#      {'parameter': '5vMvXs2-9Uc'}]},
#    {'id': '104841804589413375',
#     'vods': [{'parameter': 'B2LI3kfcXEY'},
#      {'parameter': 'NyEKiiiur5Y'},
#      {'parameter': '_LbAfwLGa-Y'},
#      {'parameter': 'ju-buSpPSlU'}]},
#    {'id': '104841804589413376',
#     'vods': [{'parameter': 'M7s2dLGDoYw'},
#      {'parameter': 'OMpXDCRf0Dw'},
#      {'parameter': 'PU5xJLBhRCU'},
#      {'parameter': 'z43KlKtudmA'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589413371',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'SUP',
#      'image': 'http://static.lolesports.com/teams/1600193815727_SuperMassiveEsportsSUP-01-FullonDark.png',
#      'name': 'Papara SuperMassive',
#      'result': {'gameWins': 3}},
#     {'code': 'MAD',
#      'image': 'http://static.lolesports.com/teams/1592591395339_MadLionsMAD-01-FullonDark.png',
#      'name': 'MAD Lions',
#      'result': {'gameWins': 2}}],
#    'type': 'normal'},
#   'startTime': '2020-09-29T10:00:00Z'},
#  {'blockName': '플레이-인 토너먼트 스테이지',
#   'games': [{'id': '104841804589478920',
#     'vods': [{'parameter': '-qjoag3d1WY'},
#      {'parameter': 'WZL3-HoqnJE'},
#      {'parameter': 'dqndAWHXG78'},
#      {'parameter': 'sydi2tQH4Ek'}]},
#    {'id': '104841804589478921',
#     'vods': [{'parameter': 'zV46zmXJA28'},
#      {'parameter': 'cC_QUXTo-68'},
#      {'parameter': '5nivHNPuawc'},
#      {'parameter': '0tBn6x59B4E'}]},
#    {'id': '104841804589478922',
#     'vods': [{'parameter': '5nvcEyi6qg8'},
#      {'parameter': '-T6nj6G_evg'},
#      {'parameter': 'WTNaWvwWGkc'},
#      {'parameter': 'CM9NTruzRXE'}]},
#    {'id': '104841804589478923', 'vods': []},
#    {'id': '104841804589478924', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478919',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'LGC',
#      'image': 'http://static.lolesports.com/teams/LegacyEsportsLGC-01-FullonDark.png',
#      'name': 'Legacy Esports',
#      'result': {'gameWins': 0}},
#     {'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 3}}],
#    'type': 'normal'},
#   'startTime': '2020-09-30T06:00:00Z'},
#  {'blockName': '플레이-인 토너먼트 스테이지',
#   'games': [{'id': '104841804589478926',
#     'vods': [{'parameter': 'UBldzirQmtk'},
#      {'parameter': '53ACuJNf3fI'},
#      {'parameter': 'ravTCHWbmKc'},
#      {'parameter': '4rSFuW7Z0M8'}]},
#    {'id': '104841804589478927',
#     'vods': [{'parameter': 'EXlI716pFyw'},
#      {'parameter': '9YT_4vcJv7Q'},
#      {'parameter': 'J1PdAt1kJqE'},
#      {'parameter': '15gUAnKcwsY'}]},
#    {'id': '104841804589478928',
#     'vods': [{'parameter': 'iYuMNWbiCPA'},
#      {'parameter': 'JD-8vSwN-3Y'},
#      {'parameter': 'zhkguv_PZgM'},
#      {'parameter': 'ZvH-4IuHtZg'}]},
#    {'id': '104841804589478929', 'vods': []},
#    {'id': '104841804589478930', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478925',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 3}},
#     {'code': 'SUP',
#      'image': 'http://static.lolesports.com/teams/1600193815727_SuperMassiveEsportsSUP-01-FullonDark.png',
#      'name': 'Papara SuperMassive',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-09-30T10:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544542',
#     'vods': [{'parameter': '_txHy0BjXBA'},
#      {'parameter': 'Sol2dNKeyLw'},
#      {'parameter': '3MRg8NUM3BU'},
#      {'parameter': 'XlQnxdsLZ6A'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544541',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'FLY',
#      'image': 'http://static.lolesports.com/teams/1592590438547_FlyQuestFLY-01-FullonDark.png',
#      'name': 'FlyQuest',
#      'result': {'gameWins': 0}},
#     {'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-03T08:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544548',
#     'vods': [{'parameter': 'B1P4sYMGkv8'},
#      {'parameter': 'YK2qCvviAR0'},
#      {'parameter': 'NSYwpQ4bhoA'},
#      {'parameter': 'zEa8JX1aSzM'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544547',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}},
#     {'code': 'DRX',
#      'image': 'http://static.lolesports.com/teams/1592589284897_DRXDRX-01-FullonDark.png',
#      'name': 'DRX',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-03T09:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478966',
#     'vods': [{'parameter': 'Kjz8sQ41sSE'},
#      {'parameter': 'Q8ikkr_Ua_I'},
#      {'parameter': 'Lb8g4GkDQTQ'},
#      {'parameter': 'WuSOAAEGJC0'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478965',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'RGE',
#      'image': 'http://static.lolesports.com/teams/1592591512937_RogueRGE-01-FullonDark.png',
#      'name': 'Rogue',
#      'result': {'gameWins': 1}},
#     {'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-03T10:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478956',
#     'vods': [{'parameter': 'wGO6r9w27TY'},
#      {'parameter': 'WuavkvLCvm4'},
#      {'parameter': 'KMee92N0ZBc'},
#      {'parameter': 'cFlEvTiat6g'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478955',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'DWG',
#      'image': 'http://static.lolesports.com/teams/1592589259480_DamwonGamingDWG-01-FullonDark.png',
#      'name': 'DAMWON Gaming',
#      'result': {'gameWins': 1}},
#     {'code': 'JDG',
#      'image': 'http://static.lolesports.com/teams/1592591827851_JDGamingJDG-01-FullonDark.png',
#      'name': 'JD Gaming',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-03T11:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478990',
#     'vods': [{'parameter': 'CKx5mshVrmE'},
#      {'parameter': 'SY45Ab4PgrI'},
#      {'parameter': 'jZcbGDHl16A'},
#      {'parameter': 'WQFuiP0MMOU'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478989',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'GEN',
#      'image': 'http://static.lolesports.com/teams/1592589327622_Gen.GGEN-01-FullonDark.png',
#      'name': 'Gen.G',
#      'result': {'gameWins': 1}},
#     {'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-03T12:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478980',
#     'vods': [{'parameter': 'Vuf95U8bYQY'},
#      {'parameter': '0Y1HnnPavv8'},
#      {'parameter': 'tGXvYs49Hcc'},
#      {'parameter': 'UJJcu2f-MWU'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478979',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TSM',
#      'image': 'http://static.lolesports.com/teams/1592590917094_TSMTSM-01-FullonDark.png',
#      'name': 'TSM',
#      'result': {'gameWins': 0}},
#     {'code': 'FNC',
#      'image': 'http://static.lolesports.com/teams/1592591295307_FnaticFNC-01-FullonDark.png',
#      'name': 'Fnatic',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-03T13:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478942',
#     'vods': [{'parameter': 'L7Q3UFwOHYM'},
#      {'parameter': 'Bk6ly65Wl7s'},
#      {'parameter': 'qqWqcnxLKzA'},
#      {'parameter': 'DhGa0iEXJf4'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478941',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'MCX',
#      'image': 'http://static.lolesports.com/teams/1592588618196_MachiMCX-01-FullonDark.png',
#      'name': 'Machi Esports',
#      'result': {'gameWins': 1}},
#     {'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-04T08:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478932',
#     'vods': [{'parameter': 'kedHaPEaQQI'},
#      {'parameter': 'CK1TWEi1XL8'},
#      {'parameter': 'QyjWL-mPoRc'},
#      {'parameter': 'QwLqGkP7Jos'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478931',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 1}},
#     {'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-04T09:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478958',
#     'vods': [{'parameter': 'CDG8wQVhP3o'},
#      {'parameter': '-ln2duwnyuk'},
#      {'parameter': 'FngH9F34kTk'},
#      {'parameter': '9iJXSSlIrcc'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478957',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'RGE',
#      'image': 'http://static.lolesports.com/teams/1592591512937_RogueRGE-01-FullonDark.png',
#      'name': 'Rogue',
#      'result': {'gameWins': 0}},
#     {'code': 'DWG',
#      'image': 'http://static.lolesports.com/teams/1592589259480_DamwonGamingDWG-01-FullonDark.png',
#      'name': 'DAMWON Gaming',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-04T10:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478964',
#     'vods': [{'parameter': 'YXRyWpNDUb8'},
#      {'parameter': '6FlU_D_ywmg'},
#      {'parameter': '9qKQe1ABWI0'},
#      {'parameter': 'rko2n0kwlr4'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478963',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 0}},
#     {'code': 'JDG',
#      'image': 'http://static.lolesports.com/teams/1592591827851_JDGamingJDG-01-FullonDark.png',
#      'name': 'JD Gaming',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-04T11:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478982',
#     'vods': [{'parameter': 'fXhnVwl91BQ'},
#      {'parameter': '6PAAOG8y6zQ'},
#      {'parameter': 'EDCoGD4_VZs'},
#      {'parameter': 'XTXr7Y0UVO4'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478981',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'GEN',
#      'image': 'http://static.lolesports.com/teams/1592589327622_Gen.GGEN-01-FullonDark.png',
#      'name': 'Gen.G',
#      'result': {'gameWins': 1}},
#     {'code': 'TSM',
#      'image': 'http://static.lolesports.com/teams/1592590917094_TSMTSM-01-FullonDark.png',
#      'name': 'TSM',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-04T12:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478988',
#     'vods': [{'parameter': 'AhSGuSCYP_w'},
#      {'parameter': 'IANHI31D6kU'},
#      {'parameter': 'AKyTdVhLEOo'},
#      {'parameter': 'bKvjA2fRP8Q'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478987',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 1}},
#     {'code': 'FNC',
#      'image': 'http://static.lolesports.com/teams/1592591295307_FnaticFNC-01-FullonDark.png',
#      'name': 'Fnatic',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-04T13:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478934',
#     'vods': [{'parameter': 's6TkGcVlLQ0'},
#      {'parameter': 'TvRUtI8gBOg'},
#      {'parameter': '8TAeKNLQKEM'},
#      {'parameter': 'OOBNgB47rQ8'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478933',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'MCX',
#      'image': 'http://static.lolesports.com/teams/1592588618196_MachiMCX-01-FullonDark.png',
#      'name': 'Machi Esports',
#      'result': {'gameWins': 0}},
#     {'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-05T08:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478940',
#     'vods': [{'parameter': 'jo08OwGnwyw'},
#      {'parameter': '8L6YFGKS28s'},
#      {'parameter': 'pZjeLhpt5HQ'},
#      {'parameter': 'Zv2eeWcPUbs'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478939',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 0}},
#     {'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-05T09:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478960',
#     'vods': [{'parameter': '8wUyP7LVPdw'},
#      {'parameter': 'v02hnBJHKPM'},
#      {'parameter': '6X80t1OV0Hs'},
#      {'parameter': 'mvChlJEuVg4'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478959',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'DWG',
#      'image': 'http://static.lolesports.com/teams/1592589259480_DamwonGamingDWG-01-FullonDark.png',
#      'name': 'DAMWON Gaming',
#      'result': {'gameWins': 1}},
#     {'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-05T10:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478962',
#     'vods': [{'parameter': 'w1pH98U9amo'},
#      {'parameter': 'PNsVmY_rkvc'},
#      {'parameter': 'ViS_kHUw9ec'},
#      {'parameter': 'MwXiLQN68Zg'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478961',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'JDG',
#      'image': 'http://static.lolesports.com/teams/1592591827851_JDGamingJDG-01-FullonDark.png',
#      'name': 'JD Gaming',
#      'result': {'gameWins': 1}},
#     {'code': 'RGE',
#      'image': 'http://static.lolesports.com/teams/1592591512937_RogueRGE-01-FullonDark.png',
#      'name': 'Rogue',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-05T11:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544550',
#     'vods': [{'parameter': 'BiElFM-p_w4'},
#      {'parameter': 'GKQR7JQuj3o'},
#      {'parameter': 'SX7SNna15kY'},
#      {'parameter': 'HrAXuJGcEa4'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544549',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'FLY',
#      'image': 'http://static.lolesports.com/teams/1592590438547_FlyQuestFLY-01-FullonDark.png',
#      'name': 'FlyQuest',
#      'result': {'gameWins': 1}},
#     {'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-05T12:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544540',
#     'vods': [{'parameter': 'UzC-_52as98'},
#      {'parameter': 'YnAFFBFE-9s'},
#      {'parameter': 'WHMNFR0IKms'},
#      {'parameter': 'DuhV4vPAWNM'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544539',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 1}},
#     {'code': 'DRX',
#      'image': 'http://static.lolesports.com/teams/1592589284897_DRXDRX-01-FullonDark.png',
#      'name': 'DRX',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-05T13:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478936',
#     'vods': [{'parameter': 'onybrPhBR_I'},
#      {'parameter': 'S1uZsSFS82I'},
#      {'parameter': 'Ai-N02YKrLs'},
#      {'parameter': 'RHXrmsK517s'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478935',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 0}},
#     {'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-06T08:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478938',
#     'vods': [{'parameter': '8WZGFHeZtCU'},
#      {'parameter': 'BRwHVHc8ADw'},
#      {'parameter': 'ZciUEIM6Bws'},
#      {'parameter': 'eiN81eg2kiQ'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478937',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 1}},
#     {'code': 'MCX',
#      'image': 'http://static.lolesports.com/teams/1592588618196_MachiMCX-01-FullonDark.png',
#      'name': 'Machi Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-06T09:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544546',
#     'vods': [{'parameter': 'JV22iqbLd24'},
#      {'parameter': 'hs2iy_JKYI8'},
#      {'parameter': '_bpCDIxFEoY'},
#      {'parameter': '0-VjWGZG23o'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544545',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'DRX',
#      'image': 'http://static.lolesports.com/teams/1592589284897_DRXDRX-01-FullonDark.png',
#      'name': 'DRX',
#      'result': {'gameWins': 1}},
#     {'code': 'FLY',
#      'image': 'http://static.lolesports.com/teams/1592590438547_FlyQuestFLY-01-FullonDark.png',
#      'name': 'FlyQuest',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-06T10:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544544',
#     'vods': [{'parameter': '8UYGNcMlLiw'},
#      {'parameter': 'WXrl9jxUT1A'},
#      {'parameter': 'PJ7vwoStZiY'},
#      {'parameter': 'owr1YsMzD5E'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544543',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 1}},
#     {'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-06T11:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478986',
#     'vods': [{'parameter': 'koIZaUxyKrE'},
#      {'parameter': 'rOt3qYbA1bg'},
#      {'parameter': 'bpCOkVGwYkg'},
#      {'parameter': 'K0ihTUykZ4w'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478985',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'FNC',
#      'image': 'http://static.lolesports.com/teams/1592591295307_FnaticFNC-01-FullonDark.png',
#      'name': 'Fnatic',
#      'result': {'gameWins': 1}},
#     {'code': 'GEN',
#      'image': 'http://static.lolesports.com/teams/1592589327622_Gen.GGEN-01-FullonDark.png',
#      'name': 'Gen.G',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-06T12:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478984',
#     'vods': [{'parameter': '6WrcsWD0H1U'},
#      {'parameter': '5j8L3hyliwU'},
#      {'parameter': '7hUUYoFr5X4'},
#      {'parameter': 'C7dAyvAjIG8'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478983',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TSM',
#      'image': 'http://static.lolesports.com/teams/1592590917094_TSMTSM-01-FullonDark.png',
#      'name': 'TSM',
#      'result': {'gameWins': 0}},
#     {'code': 'LGD',
#      'image': 'http://static.lolesports.com/teams/1592591876371_LGDGamingLGD-01-FullonDark.png',
#      'name': 'LGD Gaming',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-06T13:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478948',
#     'vods': [{'parameter': 'XkSlkhWATzM'},
#      {'parameter': 'ygBxncWXY58'},
#      {'parameter': 'sOeNxoHaUT8'},
#      {'parameter': 'jrQIBZLw9B8'},
#      {'parameter': '1blUvGa_DKE'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478947',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 0}},
#     {'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-08T08:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478950',
#     'vods': [{'parameter': 'WvZyuduKMYY'},
#      {'parameter': 'Y1P4m5a5A7c'},
#      {'parameter': '5Jiu7NcDxds'},
#      {'parameter': 'yIE-Nu0Mb9w'},
#      {'parameter': 'Kz9SJZK3p-k'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478949',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'MCX',
#      'image': 'http://static.lolesports.com/teams/1592588618196_MachiMCX-01-FullonDark.png',
#      'name': 'Machi Esports',
#      'result': {'gameWins': 0}},
#     {'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-08T09:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478946',
#     'vods': [{'parameter': 'PqJ0V0LtNPU'},
#      {'parameter': 'P9OCugmz2Iw'},
#      {'parameter': 'VIFFI4pVrVY'},
#      {'parameter': 'X3695AuXCuI'},
#      {'parameter': '9dujVSHlqRE'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478945',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 1}},
#     {'code': 'MCX',
#      'image': 'http://static.lolesports.com/teams/1592588618196_MachiMCX-01-FullonDark.png',
#      'name': 'Machi Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-08T10:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478952',
#     'vods': [{'parameter': 'uo9Rd8rFpa0'},
#      {'parameter': 'HIu-RmRBxqE'},
#      {'parameter': 'wRD6P2Fv2kU'},
#      {'parameter': '6mdAXXsSKuE'},
#      {'parameter': 'fTCwK02hfpk'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478951',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 0}},
#     {'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-08T11:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478954',
#     'vods': [{'parameter': 'Hzc7rofMuXo'},
#      {'parameter': 'T2rjfRnKP-Y'},
#      {'parameter': '1LnIiC0m18M'},
#      {'parameter': '57S4-rwSPus'},
#      {'parameter': 'CyeG0ra249k'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478953',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TL',
#      'image': 'http://static.lolesports.com/teams/1592590875575_TeamLiquidTL-01-FullonDark.png',
#      'name': 'Team Liquid',
#      'result': {'gameWins': 1}},
#     {'code': 'MCX',
#      'image': 'http://static.lolesports.com/teams/1592588618196_MachiMCX-01-FullonDark.png',
#      'name': 'Machi Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-08T12:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478944',
#     'vods': [{'parameter': 'N5VjNv6bD50'},
#      {'parameter': 'F4gWsWmhlk8'},
#      {'parameter': 'Azolp3YS8JA'},
#      {'parameter': '7qk2bcMD4jo'},
#      {'parameter': 'l6xpv0YdzAo'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478943',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 1}},
#     {'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-08T13:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104999362765783335',
#     'vods': [{'parameter': 'axOEj4MmB7E'},
#      {'parameter': '0kLPzEJnWw0'},
#      {'parameter': 'mc31j4qitXI'},
#      {'parameter': 'N6H3CblWC8Q'},
#      {'parameter': 'mdaiH3RRXYg'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104999362765717798',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 1}},
#     {'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 0}}],
#    'type': 'tiebreaker'},
#   'startTime': '2020-10-08T14:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589478972',
#     'vods': [{'parameter': 'WdfCzSLvz58'},
#      {'parameter': 'ycx0u2tuPh0'},
#      {'parameter': 'a4c080fb3Cs'},
#      {'parameter': '-vel01vS-Eg'},
#      {'parameter': 'r-1uh_8MVZk'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589478971',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'PSG',
#      'image': 'http://static.lolesports.com/teams/1600106840359_TalonPSG-01-FullonDark1.png',
#      'name': 'PSG Talon',
#      'result': {'gameWins': 0}},
#     {'code': 'DWG',
#      'image': 'http://static.lolesports.com/teams/1592589259480_DamwonGamingDWG-01-FullonDark.png',
# ...
#      'name': 'TSM',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-10T12:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544534',
#     'vods': [{'parameter': 'aRTnId08x-c'},
#      {'parameter': 'VE9NuQZYTos'},
#      {'parameter': 's0lhJWWgLfc'},
#      {'parameter': 'pv1yriHkKZE'},
#      {'parameter': 'HKp2on4I46Q'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544533',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'GEN',
#      'image': 'http://static.lolesports.com/teams/1592589327622_Gen.GGEN-01-FullonDark.png',
#      'name': 'Gen.G',
#      'result': {'gameWins': 1}},
#     {'code': 'FNC',
#      'image': 'http://static.lolesports.com/teams/1592591295307_FnaticFNC-01-FullonDark.png',
#      'name': 'Fnatic',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-10T13:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544558',
#     'vods': [{'parameter': 'nPUTJR8eHIE'},
#      {'parameter': '9qGo4ACFt20'},
#      {'parameter': 'wf5ru1stn_M'},
#      {'parameter': '4swajXsOB2A'},
#      {'parameter': 'dFFjrR4w1Xc'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544557',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'FLY',
#      'image': 'http://static.lolesports.com/teams/1592590438547_FlyQuestFLY-01-FullonDark.png',
#      'name': 'FlyQuest',
#      'result': {'gameWins': 0}},
#     {'code': 'DRX',
#      'image': 'http://static.lolesports.com/teams/1592589284897_DRXDRX-01-FullonDark.png',
#      'name': 'DRX',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-11T08:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544556',
#     'vods': [{'parameter': '_vmk8_zSYPo'},
#      {'parameter': 'ZE6XQqTzJKk'},
#      {'parameter': 'hSkBT3_LA_A'},
#      {'parameter': 'bUM_hEF0ukQ'},
#      {'parameter': 'IzT_3Cd8Yqk'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544555',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}},
#     {'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-11T09:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544560',
#     'vods': [{'parameter': 'JJ9eyq5kLHo'},
#      {'parameter': 'kFwokIWnezY'},
#      {'parameter': '2YnG6u0u_rE'},
#      {'parameter': 'dBUXzYkyIhM'},
#      {'parameter': '5xkLz2LQaXk'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544559',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'DRX',
#      'image': 'http://static.lolesports.com/teams/1592589284897_DRXDRX-01-FullonDark.png',
#      'name': 'DRX',
#      'result': {'gameWins': 1}},
#     {'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-11T10:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544554',
#     'vods': [{'parameter': '3AmYj_omWWA'},
#      {'parameter': 'I8KUqYTmMTM'},
#      {'parameter': 'dH-iOHaaueM'},
#      {'parameter': 'KUtOtFs3Ur4'},
#      {'parameter': 'BHmasfEHux8'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544553',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 0}},
#     {'code': 'FLY',
#      'image': 'http://static.lolesports.com/teams/1592590438547_FlyQuestFLY-01-FullonDark.png',
#      'name': 'FlyQuest',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-11T11:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544562',
#     'vods': [{'parameter': 'DfdfGiCqAtE'},
#      {'parameter': 'GKkOCzTp1bQ'},
#      {'parameter': '52MbuKJ3i2o'},
#      {'parameter': 'UeKb9Ep7A6g'},
#      {'parameter': 'M2LEZxS339s'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544561',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'UOL',
#      'image': 'https://lolstatic-a.akamaihd.net/esports-assets/production/team/unicorns-of-love-8qvakeja.png',
#      'name': 'Unicorns of Love',
#      'result': {'gameWins': 0}},
#     {'code': 'FLY',
#      'image': 'http://static.lolesports.com/teams/1592590438547_FlyQuestFLY-01-FullonDark.png',
#      'name': 'FlyQuest',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-11T12:00:00Z'},
#  {'blockName': '그룹',
#   'games': [{'id': '104841804589544552',
#     'vods': [{'parameter': 'S3Wz6AtDFa4'},
#      {'parameter': 'p239GIolN60'},
#      {'parameter': 'Hizz4fsgZq8'},
#      {'parameter': '1pX9s6Sl9Dc'},
#      {'parameter': 'okKbNYHvc7w'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544551',
#    'strategy': {'count': 1, 'type': 'bestOf'},
#    'teams': [{'code': 'DRX',
#      'image': 'http://static.lolesports.com/teams/1592589284897_DRXDRX-01-FullonDark.png',
#      'name': 'DRX',
#      'result': {'gameWins': 0}},
#     {'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-11T13:00:00Z'},
#  {'blockName': '토너먼트 스테이지',
#   'games': [{'id': '104841804589544582',
#     'vods': [{'parameter': 'CTxK2tDyWkU'},
#      {'parameter': 'rdV6mvpvBL4'},
#      {'parameter': 'QMbN9c_XaUQ'},
#      {'parameter': 'b9JfnRMEMv0'},
#      {'parameter': 'o-wUCthx0Qg'}]},
#    {'id': '104841804589544583',
#     'vods': [{'parameter': 'kBgH6whWIsE'},
#      {'parameter': 'SG4NBRKNkzQ'},
#      {'parameter': 'qI4qNY3Hv10'},
#      {'parameter': 'qVwBBWdawMs'},
#      {'parameter': 'uB318QlBqFw'}]},
#    {'id': '104841804589544584',
#     'vods': [{'parameter': 'jOlpRkj2gYY'},
#      {'parameter': 'OQ7aSsAVmsU'},
#      {'parameter': 'OQ7aSsAVmsU'},
#      {'parameter': 'bSkja-bwGHs'},
#      {'parameter': '3ovoYDafNWc'},
#      {'parameter': 'rMCUvwKQDQk'}]},
#    {'id': '104841804589544585', 'vods': []},
#    {'id': '104841804589544586', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544581',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'DRX',
#      'image': 'http://static.lolesports.com/teams/1592589284897_DRXDRX-01-FullonDark.png',
#      'name': 'DRX',
#      'result': {'gameWins': 0}},
#     {'code': 'DWG',
#      'image': 'http://static.lolesports.com/teams/1592589259480_DamwonGamingDWG-01-FullonDark.png',
#      'name': 'DAMWON Gaming',
#      'result': {'gameWins': 3}}],
#    'type': 'normal'},
#   'startTime': '2020-10-15T10:00:00Z'},
#  {'blockName': '토너먼트 스테이지',
#   'games': [{'id': '104841804589544570',
#     'vods': [{'parameter': 'qXxN3uE8024'},
#      {'parameter': 'foFHMg9JnoM'},
#      {'parameter': 'taL3KTy9A-8'},
#      {'parameter': 'tUe8xu01dNs'},
#      {'parameter': 'kP6RHEYoMmo'}]},
#    {'id': '104841804589544571',
#     'vods': [{'parameter': 'jYaPWKd7lM4'},
#      {'parameter': '_zLjyjLkYLQ'},
#      {'parameter': 'Z4ajhmZCeo8'},
#      {'parameter': 'ZbZyJQvK_cg'},
#      {'parameter': 'fM4JEHFvl_0'}]},
#    {'id': '104841804589544572',
#     'vods': [{'parameter': '3wnTs--Cdsw'},
#      {'parameter': 'rmCgpDKAQL8'},
#      {'parameter': 'sx6IXolV3lE'},
#      {'parameter': '-cvPGOBzElU'},
#      {'parameter': 'oIKxfTiMOlk'}]},
#    {'id': '104841804589544573',
#     'vods': [{'parameter': '2jaQM0BLhKg'},
#      {'parameter': 'AujnjOVNuPM'},
#      {'parameter': 'tv-O9-kScmU'},
#      {'parameter': 'zt1bz2MYNKQ'},
#      {'parameter': 'GnJYjoMZjPY'}]},
#    {'id': '104841804589544574', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544569',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'JDG',
#      'image': 'http://static.lolesports.com/teams/1592591827851_JDGamingJDG-01-FullonDark.png',
#      'name': 'JD Gaming',
#      'result': {'gameWins': 1}},
#     {'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 3}}],
#    'type': 'normal'},
#   'startTime': '2020-10-16T10:00:00Z'},
#  {'blockName': '토너먼트 스테이지',
#   'games': [{'id': '104841804589544564',
#     'vods': [{'parameter': 'oXEFwheiX9U'},
#      {'parameter': 'KSHH-IYchw0'},
#      {'parameter': 'AOxhoY9kdhY'},
#      {'parameter': 'FQkZWPb1kIc'},
#      {'parameter': '1Epz9B6OCPQ'}]},
#    {'id': '104841804589544565',
#     'vods': [{'parameter': 'NJPbzf06Wgg'},
#      {'parameter': '_b7S-DYZwEU'},
#      {'parameter': 'hGLfzHIhWK4'},
#      {'parameter': '2nrFDFxet-8'},
#      {'parameter': 'hixjcleF3Tg'}]},
#    {'id': '104841804589544566',
#     'vods': [{'parameter': 'NZo7pXcnE-M'},
#      {'parameter': 'BAH3pSjGETA'},
#      {'parameter': 'RFsdm2DJyeY'},
#      {'parameter': 't-v_jvW-xHg'},
#      {'parameter': '09XVE2w3ytw'}]},
#    {'id': '104841804589544567',
#     'vods': [{'parameter': 'XZlSgg5DYIo'},
#      {'parameter': 'BbyruWykCJg'},
#      {'parameter': 'X82Oq4MeuXo'},
#      {'parameter': 'FKKUygAkJZU'},
#      {'parameter': 'HKQQb-_yJXI'}]},
#    {'id': '104841804589544568',
#     'vods': [{'parameter': 'QXcfiDFgthY'},
#      {'parameter': 'Ve7JCdT_03k'},
#      {'parameter': 'VvHiAGBQqTU'},
#      {'parameter': '36zrUbudhuM'},
#      {'parameter': 'T8zD53ZVcH4'}]}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544563',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'FNC',
#      'image': 'http://static.lolesports.com/teams/1592591295307_FnaticFNC-01-FullonDark.png',
#      'name': 'Fnatic',
#      'result': {'gameWins': 2}},
#     {'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 3}}],
#    'type': 'normal'},
#   'startTime': '2020-10-17T10:00:00Z'},
#  {'blockName': '토너먼트 스테이지',
#   'games': [{'id': '104841804589544576',
#     'vods': [{'parameter': '4TjOoy_fupE'},
#      {'parameter': 'qly1UedkSps'},
#      {'parameter': 'gGQO4pe5QK8'},
#      {'parameter': 'IM4dXM9Tpqk'},
#      {'parameter': 'bUyoiic-2Do'}]},
#    {'id': '104841804589544577',
#     'vods': [{'parameter': 'JmvomX6larM'},
#      {'parameter': '2ZF44LIQ7LY'},
#      {'parameter': '27pUd9R0U4I'},
#      {'parameter': 'hB76k4p_zV8'},
#      {'parameter': 'GN4iGHh5hoc'}]},
#    {'id': '104841804589544578',
#     'vods': [{'parameter': 'sZ_dmTXMn4s'},
#      {'parameter': 'aWMa86rPEY0'},
#      {'parameter': 'HrVnpyAoHWQ'},
#      {'parameter': 'SeQ4o7Hzn5I'},
#      {'parameter': 'i3meHek8bqA'}]},
#    {'id': '104841804589544579', 'vods': []},
#    {'id': '104841804589544580', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544575',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 3}},
#     {'code': 'GEN',
#      'image': 'http://static.lolesports.com/teams/1592589327622_Gen.GGEN-01-FullonDark.png',
#      'name': 'Gen.G',
#      'result': {'gameWins': 0}}],
#    'type': 'normal'},
#   'startTime': '2020-10-18T10:00:00Z'},
#  {'blockName': '토너먼트 스테이지',
#   'games': [{'id': '104841804589544594',
#     'vods': [{'parameter': 'F9PZIypclmA'},
#      {'parameter': '41uTZKwjnMo'},
#      {'parameter': 'MCNV2LM_Msc'},
#      {'parameter': 'FrNaRCcgMNQ'},
#      {'parameter': 'yLmZIGERTrY'}]},
#    {'id': '104841804589544595',
#     'vods': [{'parameter': 'qx-L0IcBMvI'},
#      {'parameter': '4tcxeVp9lBQ'},
#      {'parameter': 'zqAwPPs-xP8'},
#      {'parameter': 'XvKTQZzdbDk'},
#      {'parameter': 'KYkoHtZifSY'}]},
#    {'id': '104841804589544596',
#     'vods': [{'parameter': 'bICVGiqIlBU'},
#      {'parameter': 'TDNJDiFY0sg'},
#      {'parameter': 'NEFI4zhQ2NA'},
#      {'parameter': 'e1t3WmiIGUE'},
#      {'parameter': '5s0HqgIETBw'}]},
#    {'id': '104841804589544597',
#     'vods': [{'parameter': 'B_tR-yTqw3k'},
#      {'parameter': 'aCYPaBIyC3I'},
#      {'parameter': 'fNxkcMU_wyU'},
#      {'parameter': 'KUwRVTflqZo'},
#      {'parameter': 'hzt5DCCNluU'}]},
#    {'id': '104841804589544598', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544593',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'DWG',
#      'image': 'http://static.lolesports.com/teams/1592589259480_DamwonGamingDWG-01-FullonDark.png',
#      'name': 'DAMWON Gaming',
#      'result': {'gameWins': 3}},
#     {'code': 'G2',
#      'image': 'http://static.lolesports.com/teams/1592591333874_G2G2-01-FullonDark.png',
#      'name': 'G2 Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-24T10:00:00Z'},
#  {'blockName': '토너먼트 스테이지',
#   'games': [{'id': '104841804589544588',
#     'vods': [{'parameter': '6RV6sQyGPl4'},
#      {'parameter': 'N8Mi0jlpIJk'},
#      {'parameter': '9--M8BEgzEM'},
#      {'parameter': 'LbeJJ3FSw_A'},
#      {'parameter': 'J2EB_aQpW1Y'}]},
#    {'id': '104841804589544589',
#     'vods': [{'parameter': 'ZIZNXOd8kxQ'},
#      {'parameter': 'NHjZZFleBsc'},
#      {'parameter': 'NHi9QtucXDM'},
#      {'parameter': 'r4lRp8oqLDA'},
#      {'parameter': 'Y0VYpjuQIcE'}]},
#    {'id': '104841804589544590',
#     'vods': [{'parameter': 'ZAbkO7UUpQQ'},
#      {'parameter': 'A36lcIs3Mpo'},
#      {'parameter': 'DEcq6lYRU00'},
#      {'parameter': 'a8f-3FwsyVQ'},
#      {'parameter': 'CpoUS1j8N5U'}]},
#    {'id': '104841804589544591',
#     'vods': [{'parameter': 'xOQS1_cXcxM'},
#      {'parameter': 'D-7zC57ZAsI'},
#      {'parameter': '3qGrqibx8VE'},
#      {'parameter': 'O9g3nhHBuA4'},
#      {'parameter': 'bn6651OgKBk'}]},
#    {'id': '104841804589544592', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544587',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 3}},
#     {'code': 'TES',
#      'image': 'http://static.lolesports.com/teams/1592592064571_TopEsportsTES-01-FullonDark.png',
#      'name': 'Top Esports',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-25T10:00:00Z'},
#  {'blockName': '토너먼트 스테이지',
#   'games': [{'id': '104841804589544600',
#     'vods': [{'parameter': 'ulboa1kHp8U'},
#      {'parameter': '--OpGqXK16c'},
#      {'parameter': 'IOYFDSaoMhw'},
#      {'parameter': 'eXYlQkG8_C0'},
#      {'parameter': 'WTN1GW2UNLE'}]},
#    {'id': '104841804589610137',
#     'vods': [{'parameter': 'u8Sy6rQ8Yf8'},
#      {'parameter': 'NAO9jke5S3I'},
#      {'parameter': 'xYx0zXLq7hk'},
#      {'parameter': 'tAlp0W3WSjw'},
#      {'parameter': 'smoIkgK1w08'}]},
#    {'id': '104841804589610138',
#     'vods': [{'parameter': 'JsPF3ZaIXdU'},
#      {'parameter': 'NyJs-_WU63o'},
#      {'parameter': 'i0qPuQyea_8'},
#      {'parameter': 'UAmmIkI0s-Y'}]},
#    {'id': '104841804589610139',
#     'vods': [{'parameter': 'myCz7BxvKsw'},
#      {'parameter': 'ea4q5t2pYLQ'},
#      {'parameter': 'ea4q5t2pYLQ'},
#      {'parameter': 'I2JZOiMA7g8'},
#      {'parameter': 'WzoOzbUcUbE'}]},
#    {'id': '104841804589610140', 'vods': []}],
#   'league': {'name': '월드 챔피언십'},
#   'match': {'id': '104841804589544599',
#    'strategy': {'count': 5, 'type': 'bestOf'},
#    'teams': [{'code': 'DWG',
#      'image': 'http://static.lolesports.com/teams/1592589259480_DamwonGamingDWG-01-FullonDark.png',
#      'name': 'DAMWON Gaming',
#      'result': {'gameWins': 3}},
#     {'code': 'SN',
#      'image': 'http://static.lolesports.com/teams/1592592023323_SuningSN-01-FullonDark.png',
#      'name': 'Suning',
#      'result': {'gameWins': 1}}],
#    'type': 'normal'},
#   'startTime': '2020-10-31T10:00:00Z'}]

# %%
#world championship games list
name_list=[]
game_list = []

# %%
for i in data['data']['schedule']['events']:
    temp = []
    for j in i['match']['teams']:
        temp.append(j['code'])
    temp.append(i['startTime'])
    for j in i['games']:
        if len(j['vods']) is not 0:
            temp.append(j['id'])
    game_list.append(temp)

# %%
game_list
# Out:
# [['MAD', 'ITZ', '2020-09-25T08:00:00Z', '104841804589413344'],
#  ['PSG', 'R7', '2020-09-25T09:00:00Z', '104841804589413364'],
#  ['LGC', 'ITZ', '2020-09-25T10:00:00Z', '104841804589413348'],
#  ['LGD', 'PSG', '2020-09-25T11:00:00Z', '104841804589413352'],
#  ['TL', 'MAD', '2020-09-25T12:00:00Z', '104841804589151188'],
#  ['R7', 'V3', '2020-09-26T08:00:00Z', '104841804589413368'],
#  ['ITZ', 'SUP', '2020-09-26T09:00:00Z', '104841804589413350'],
#  ['V3', 'UOL', '2020-09-26T10:00:00Z', '104841804589413366'],
#  ['LGD', 'R7', '2020-09-26T11:00:00Z', '104841804589413358'],
#  ['UOL', 'PSG', '2020-09-26T12:00:00Z', '104841804589413362'],
#  ['SUP', 'MAD', '2020-09-26T13:00:00Z', '104841804589413342'],
#  ['TL', 'LGC', '2020-09-26T14:00:00Z', '104841804589413334'],
#  ['V3', 'LGD', '2020-09-27T08:00:00Z', '104841804589413354'],
#  ['R7', 'UOL', '2020-09-27T09:00:00Z', '104841804589413370'],
#  ['PSG', 'V3', '2020-09-27T10:00:00Z', '104841804589413360'],
#  ['UOL', 'LGD', '2020-09-27T11:00:00Z', '104841804589413356'],
#  ['UOL', 'PSG', '2020-09-27T12:00:00Z', '104936772876713568'],
#  ['LGD', 'V3', '2020-09-27T13:00:00Z', '104936778827926888'],
#  ['SUP', 'TL', '2020-09-28T08:00:00Z', '104841804589413336'],
#  ['MAD', 'LGC', '2020-09-28T09:00:00Z', '104841804589413340'],
#  ['ITZ', 'TL', '2020-09-28T10:00:00Z', '104841804589413338'],
#  ['LGC', 'SUP', '2020-09-28T11:00:00Z', '104841804589413346'],
#  ['MAD', 'ITZ', '2020-09-28T12:00:00Z', '104942192322039819'],
#  ['TL', 'LGC', '2020-09-28T13:00:00Z', '104942405977919501'],
#  ['R7',
#   'LGD',
#   '2020-09-29T06:00:00Z',
#   '104841804589413378',
#   '104841804589413379',
#   '104841804589478916'],
#  ['SUP',
#   'MAD',
#   '2020-09-29T10:00:00Z',
#   '104841804589413372',
#   '104841804589413373',
#   '104841804589413374',
#   '104841804589413375',
#   '104841804589413376'],
#  ['LGC',
#   'LGD',
#   '2020-09-30T06:00:00Z',
#   '104841804589478920',
#   '104841804589478921',
#   '104841804589478922'],
#  ['UOL',
#   'SUP',
#   '2020-09-30T10:00:00Z',
#   '104841804589478926',
#   '104841804589478927',
#   '104841804589478928'],
#  ['FLY', 'TES', '2020-10-03T08:00:00Z', '104841804589544542'],
#  ['UOL', 'DRX', '2020-10-03T09:00:00Z', '104841804589544548'],
#  ['RGE', 'PSG', '2020-10-03T10:00:00Z', '104841804589478966'],
#  ['DWG', 'JDG', '2020-10-03T11:00:00Z', '104841804589478956'],
#  ['GEN', 'LGD', '2020-10-03T12:00:00Z', '104841804589478990'],
#  ['TSM', 'FNC', '2020-10-03T13:00:00Z', '104841804589478980'],
#  ['MCX', 'TL', '2020-10-04T08:00:00Z', '104841804589478942'],
#  ['G2', 'SN', '2020-10-04T09:00:00Z', '104841804589478932'],
#  ['RGE', 'DWG', '2020-10-04T10:00:00Z', '104841804589478958'],
#  ['PSG', 'JDG', '2020-10-04T11:00:00Z', '104841804589478964'],
#  ['GEN', 'TSM', '2020-10-04T12:00:00Z', '104841804589478982'],
#  ['LGD', 'FNC', '2020-10-04T13:00:00Z', '104841804589478988'],
#  ['MCX', 'G2', '2020-10-05T08:00:00Z', '104841804589478934'],
#  ['TL', 'SN', '2020-10-05T09:00:00Z', '104841804589478940'],
#  ['DWG', 'PSG', '2020-10-05T10:00:00Z', '104841804589478960'],
#  ['JDG', 'RGE', '2020-10-05T11:00:00Z', '104841804589478962'],
#  ['FLY', 'UOL', '2020-10-05T12:00:00Z', '104841804589544550'],
#  ['TES', 'DRX', '2020-10-05T13:00:00Z', '104841804589544540'],
#  ['G2', 'TL', '2020-10-06T08:00:00Z', '104841804589478936'],
#  ['SN', 'MCX', '2020-10-06T09:00:00Z', '104841804589478938'],
#  ['DRX', 'FLY', '2020-10-06T10:00:00Z', '104841804589544546'],
#  ['TES', 'UOL', '2020-10-06T11:00:00Z', '104841804589544544'],
#  ['FNC', 'GEN', '2020-10-06T12:00:00Z', '104841804589478986'],
#  ['TSM', 'LGD', '2020-10-06T13:00:00Z', '104841804589478984'],
#  ['TL', 'G2', '2020-10-08T08:00:00Z', '104841804589478948'],
#  ['MCX', 'SN', '2020-10-08T09:00:00Z', '104841804589478950'],
#  ['G2', 'MCX', '2020-10-08T10:00:00Z', '104841804589478946'],
#  ['SN', 'TL', '2020-10-08T11:00:00Z', '104841804589478952'],
#  ['TL', 'MCX', '2020-10-08T12:00:00Z', '104841804589478954'],
#  ['SN', 'G2', '2020-10-08T13:00:00Z', '104841804589478944'],
#  ['SN', 'G2', '2020-10-08T14:00:00Z', '104999362765783335'],
#  ['PSG', 'DWG', '2020-10-09T08:00:00Z', '104841804589478972'],
#  ['RGE', 'JDG', '2020-10-09T09:00:00Z', '104841804589478974'],
#  ['DWG', 'RGE', '2020-10-09T10:00:00Z', '104841804589478970'],
#  ['JDG', 'PSG', '2020-10-09T11:00:00Z', '104841804589478976'],
#  ['PSG', 'RGE', '2020-10-09T12:00:00Z', '104841804589478978'],
#  ['JDG', 'DWG', '2020-10-09T13:00:00Z', '104841804589478968'],
#  ['FNC', 'TSM', '2020-10-10T08:00:00Z', '104841804589478992'],
#  ['LGD', 'GEN', '2020-10-10T09:00:00Z', '104841804589544538'],
#  ['TSM', 'GEN', '2020-10-10T10:00:00Z', '104841804589544530'],
#  ['FNC', 'LGD', '2020-10-10T11:00:00Z', '104841804589544536'],
#  ['LGD', 'TSM', '2020-10-10T12:00:00Z', '104841804589544532'],
#  ['GEN', 'FNC', '2020-10-10T13:00:00Z', '104841804589544534'],
#  ['FLY', 'DRX', '2020-10-11T08:00:00Z', '104841804589544558'],
#  ['UOL', 'TES', '2020-10-11T09:00:00Z', '104841804589544556'],
#  ['DRX', 'UOL', '2020-10-11T10:00:00Z', '104841804589544560'],
#  ['TES', 'FLY', '2020-10-11T11:00:00Z', '104841804589544554'],
#  ['UOL', 'FLY', '2020-10-11T12:00:00Z', '104841804589544562'],
#  ['DRX', 'TES', '2020-10-11T13:00:00Z', '104841804589544552'],
#  ['DRX',
#   'DWG',
#   '2020-10-15T10:00:00Z',
#   '104841804589544582',
#   '104841804589544583',
#   '104841804589544584'],
#  ['JDG',
#   'SN',
#   '2020-10-16T10:00:00Z',
#   '104841804589544570',
#   '104841804589544571',
#   '104841804589544572',
#   '104841804589544573'],
#  ['FNC',
#   'TES',
#   '2020-10-17T10:00:00Z',
#   '104841804589544564',
#   '104841804589544565',
#   '104841804589544566',
#   '104841804589544567',
#   '104841804589544568'],
#  ['G2',
#   'GEN',
#   '2020-10-18T10:00:00Z',
#   '104841804589544576',
#   '104841804589544577',
#   '104841804589544578'],
#  ['DWG',
#   'G2',
#   '2020-10-24T10:00:00Z',
#   '104841804589544594',
#   '104841804589544595',
#   '104841804589544596',
#   '104841804589544597'],
#  ['SN',
#   'TES',
#   '2020-10-25T10:00:00Z',
#   '104841804589544588',
#   '104841804589544589',
#   '104841804589544590',
#   '104841804589544591'],
#  ['DWG',
#   'SN',
#   '2020-10-31T10:00:00Z',
#   '104841804589544600',
#   '104841804589610137',
#   '104841804589610138',
#   '104841804589610139']]

# %%
import pandas as pd
import numpy as np
import time

# %%
single = game_list[3]

# %%
single
# Out:
# ['LGD', 'PSG', '2020-09-25T11:00:00Z', '104841804589413352']

# %%
single[2] = single[2][:-1]+'.00Z'

# %%
gamedata = {}
#get window
import datetime
header = {'x-api-key':key}

timeframe = pd.DataFrame(np.zeros((0,2)))
timeframe.columns = ['Time','frame']

first = 0
index = 0
seconds = 0
last = 0
dead = 0
while dead == 0 :

    try:
        if first == 0:
            startT = single[2]
            timeT = datetime.datetime.strptime(startT, "%Y-%m-%dT%H:%M:%S.%fZ")
            timeT = timeT - datetime.timedelta(hours=1)
            first +=1
        else:
            if seconds == 0 :
                timeT = timeT + datetime.timedelta(minutes=1)
            else:
                timeT = timeT + datetime.timedelta(seconds=10)
        param = {'id':single[3],'startingTime':str(timeT.strftime("%Y-%m-%dT%H:%M:%S.%fZ"))}

        leagues = 'https://feed.lolesports.com/livestats/v1/window/'+str(param['id'])
        r = requests.get(leagues,headers = header,params = param)
        data = r.json()
        for i in range(len(data['frames'])):
            if len(data['frames'][i]['rfc460Timestamp']) == 20:
                data['frames'][i]['rfc460Timestamp'] = data['frames'][i]['rfc460Timestamp'][:-1]+'.00Z'

            tempTime = datetime.datetime.strptime(data['frames'][i]['rfc460Timestamp'], "%Y-%m-%dT%H:%M:%S.%fZ")

            check = str(tempTime.hour)+'-'+str(tempTime.minute)+'-'+str(tempTime.second)

            if data['frames'][i]['gameState']=='finished':
                dead = 1
                if check in list(timeframe['Time']):
                    timeframe.loc[index-1] = check,data['frames'][i]
                    continue

            if  check not in list(timeframe['Time']):
                timeframe.loc[index] = check,data['frames'][i]
                index += 1

        if seconds == 0:
            timeT = timeT - datetime.timedelta(minutes=1)
            timeframe = pd.DataFrame(np.zeros((0,2)))
            timeframe.columns = ['Time','frame']
            seconds =1

    except Exception as e:
        pass
gamedata[single[3]] = timeframe
print('finish')
# Out:
# finish

# %%
for k,v in gamedata.items():
    for i in v['frame']:
        if i['blueTeam']['totalGold'] == 0:
            gamedata[k] = gamedata[k].drop([gamedata[k].index[0]])

# %%
len(gamedata['104841804589413352'])
# Out:
# 2106

# %%
for game_id in gamedata.keys():
    gamedata[game_id]['Timestamp'] = list(map(lambda x:x['rfc460Timestamp'],gamedata[game_id]['frame'].values))
    
    gamedata[game_id]['blue_gold'] = list(map(lambda x:x['blueTeam']['totalGold'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['blue_towers'] = list(map(lambda x:x['blueTeam']['towers'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['blue_barons'] = list(map(lambda x:x['blueTeam']['barons'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['blue_totalKills'] = list(map(lambda x:x['blueTeam']['totalKills'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['blue_dragons'] = list(map(lambda x:len(x['blueTeam']['dragons']),gamedata[game_id]['frame'].values))

    gamedata[game_id]['red_gold'] = list(map(lambda x:x['redTeam']['totalGold'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['red_towers'] = list(map(lambda x:x['redTeam']['towers'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['red_barons'] = list(map(lambda x:x['redTeam']['barons'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['red_totalKills'] = list(map(lambda x:x['redTeam']['totalKills'],gamedata[game_id]['frame'].values))
    gamedata[game_id]['red_dragons'] = list(map(lambda x:len(x['redTeam']['dragons']),gamedata[game_id]['frame'].values))
    
    gamedata[game_id].drop(['frame'],axis='columns',inplace=True)
    gamedata[game_id] = gamedata[game_id].reset_index(drop=True)

# %%
for game in gamedata.keys():
    gamedata[game]['Time'] = list(map(lambda x:int(x.split('-')[0])*3600+int(x.split('-')[1])*60+int(x.split('-')[2]),gamedata[game]['Time']))

# %%
for game in gamedata.keys():
    init = gamedata[game]['Time'][0]
    gamedata[game]['Time'] = list(map(lambda x:x-init,gamedata[game]['Time']))

# %%
for game in gamedata.keys():
    temp_data= pd.DataFrame(columns = gamedata[game].columns)
    time = 0
    index = 0
    last = gamedata[game]['Time'].values[-1]
    while(time<last):
        temp = gamedata[game].iloc[[index]]
        if temp['Time'].values[0] == time:
            temp_data = pd.concat([temp_data,temp],ignore_index = True)
            index+=1
        else :
            temp['Time'] = time
            temp_data = pd.concat([temp_data,temp],ignore_index = True)
        time+=1
    gamedata[game] = temp_data
# Out:
# /home/ubuntu/yes/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
duration = 0
for key in gamedata.keys():
    duration = len(gamedata[key])

# %%
duration
# Out:
# 2241

# %%
# 논문 통계 적용
baron_statistic={}
dragon_statistic={}

highlight_add = {}

for game in gamedata.keys():
    baron_s=[]
    dragon_s=[]
    end_s=[]
    
    baron = []
    dragon = []
    end = []
    bb=0
    rb=0
    bd=0
    rd=0
    for i in range(len(gamedata[game])):
        #default -17,8  -7,5
        if gamedata[game].loc[i]['blue_barons']!=bb:
            baron_s.append(i)
            for j in range(i-20,min(i+9,len(gamedata[game]))):
                baron.append(j)
            bb = gamedata[game].loc[i]['blue_barons']
        if gamedata[game].loc[i]['red_barons']!=rb:
            baron_s.append(i)
            for j in range(i-20,min(i+9,len(gamedata[game]))):
                baron.append(j)
            rb = gamedata[game].loc[i]['red_barons']
        if gamedata[game].loc[i]['blue_dragons']!=bd:
            dragon_s.append(i)
            for j in range(i-8,min(i+4,len(gamedata[game]))):
                dragon.append(j)
            bd = gamedata[game].loc[i]['blue_dragons']
        if gamedata[game].loc[i]['red_dragons']!=rd:
            dragon_s.append(i)
            for j in range(i-8,min(i+4,len(gamedata[game]))):
                dragon.append(j)
            rd = gamedata[game].loc[i]['red_dragons']
    #for j in range(len(data[game])-48,len(data[game])):
    #        end.append(j)
    
    highlight_add[game] = baron+dragon
            
    baron_statistic[game] = baron_s
    dragon_statistic[game] = dragon_s

# %%
for game in gamedata.keys():
    gamedata[game] = gamedata[game][['blue_gold','red_gold','blue_towers','red_towers','blue_totalKills','red_totalKills']]

# %%
#normalization
for game in gamedata.keys():
    final = pd.DataFrame(columns = ['gold','tower','kill'])
    for i in range(len(gamedata[game])):
        temp =[]
        temp.append((gamedata[game]['blue_gold'][i]+1) / (gamedata[game]['blue_gold'][i]+gamedata[game]['red_gold'][i]+2))
        temp.append((gamedata[game]['blue_towers'][i]+1) / (gamedata[game]['blue_towers'][i]+gamedata[game]['red_towers'][i]+2))
        temp.append((gamedata[game]['blue_totalKills'][i]+1) / (gamedata[game]['blue_totalKills'][i]+gamedata[game]['red_totalKills'][i]+2))
        final.loc[i] = temp
        
    gamedata[game] = final

# %%
# 0. 사용할 패키지 불러오기
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
from numpy import argmax
 

# load model
from keras.models import load_model
model = load_model('/home/ubuntu/gangmin/tsvt/video/win_loss_classifier/models/344-0.0404.hdf5')

# %%
predict = {}
result = {}

# %%
for game in gamedata.keys():
    predict[game] = model.predict(gamedata[game])

# %%
highlight_re = {}
highlight_delta = {}
for game in gamedata.keys():
    predict_blue = pd.DataFrame(predict[game])
    predict_red = predict_blue[1]
    predict_blue = predict_blue[0]
    
    predict_temp = list(predict_blue)
    predict_temp.insert(0,0)
    predict_temp.pop(-1)
    
    predict_blue = abs(np.array(predict_blue)-np.array(predict_temp))
    predict_blue[0] = predict_blue[1]
    
    predict_temp = list(predict_red)
    predict_temp.insert(0,0)
    predict_temp.pop(-1)
    
    predict_red = abs(np.array(predict_red)-np.array(predict_temp))
    predict_red[0] = predict_red[1]
    
    predict_delta = predict_blue+predict_red
    
    highlight_delta[game] = predict_delta
    
    highlight = []
    for i,v in enumerate(predict_delta):
        if v>0.0085:
            highlight.append(i)
            
    highlight_re[game] = highlight

# %%
highlight_delta
highlight_re
# Out:
# {'104841804589413352': [732,
#   1066,
#   1125,
#   1211,
#   1280,
#   1370,
#   1376,
#   1453,
#   1454,
#   1572,
#   1613,
#   1614,
#   1617,
#   1656,
#   1789,
#   1792,
#   1796,
#   1797,
#   1814,
#   1826,
#   1933,
#   1963,
#   1976,
#   1977]}

# %% [markdown]
# # make one_two

# %%
for key in highlight_delta.keys():
    highlight_delta[key] = list(map(lambda x : 1 if x>0.0085 else x, highlight_delta[key]))

# %%
for key in highlight_re.keys():
    #print(tdelta[key])
    
    for index in highlight_re[key]:
        before=[]
        #before 10
        v = 1/21
        temp=v
        for i in range(20):
            before.append(temp)
            temp+=v
        
        after=[]
        #after 7
        v = 1/15
        temp=v
        for i in range(14):
            after.insert(0,temp)
            temp+=v
        total=before
        total.append(1)
        total = total+after
        ti =0
        for i in range(max(0,-20+index),min(len(highlight_delta[key]),14+index)):
            if highlight_delta[key][i] < total[ti]:
                highlight_delta[key][i] = total[ti]
            ti+=1

# %%
for key in baron_statistic.keys():
    #16,7
    for index in baron_statistic[key]:
        before=[]
        #before 10
        #v = max(delta[key])/17
        v = 1/33
        temp=v
        for i in range(32):
            before.append(temp)
            temp+=v
        
        after=[]
        #after 7
        #v = max(delta[key])/8
        v = 1/15
        temp=v
        for i in range(14):
            after.insert(0,temp)
            temp+=v
        total=before
        #total.append(max(delta[key]))
        total.append(1)
        total = total+after
        ti =0
        for i in range(max(0,-32+index),min(len(highlight_delta[key]),14+index)):
            if highlight_delta[key][i] < total[ti]:
                highlight_delta[key][i] = total[ti]
            ti+=1

# %%
for key in dragon_statistic.keys():
    #6, 3
    for index in dragon_statistic[key]:
        before=[]
        #before 10
        #v = max(delta[key])/6
        v = 1/11
        temp=v
        for i in range(10):
            before.append(temp)
            temp+=v
        
        after=[]
        #after 7
        #v = max(delta[key])/3
        v = 1/5
        temp=v
        for i in range(4):
            after.insert(0,temp)
            temp+=v
        total=before
        #total.append(max(delta[key]))
        total.append(1)
        total = total+after
        ti =0
        for i in range(max(0,-10+index),min(len(highlight_delta[key]),4+index)):
            if highlight_delta[key][i] < total[ti]:
                highlight_delta[key][i] = total[ti]
            ti+=1

# %%
for key in baron_statistic.keys():
    #6, 3
    before=[]
    #before 10
    #v = max(delta[key])/47
    v = 1/93
    temp=v
    for i in range(92):
        before.append(temp)
        temp+=v

    total=before
    #total.append(max(delta[key]))
    total.append(1)
    ti =0
    for i in range(len(highlight_delta[key])-92,len(highlight_delta[key])):
        if highlight_delta[key][i] < total[ti]:
            highlight_delta[key][i] = total[ti]
        ti+=1

# %%
highlight_delta
