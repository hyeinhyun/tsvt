# %% [markdown]
# # evaluation

# %%
import numpy as np
import pickle
with open('/home/ubuntu/gangmin/tsvt/video/lolData/exp_data/highlight_frames.pickle',"rb") as f:
    frames = pickle.load(f)

# %%
frames
# Out:
# {'102844212428895431': array([0., 0., 0., ..., 1., 1., 1.]),
#  '102844212429092040': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212429288649': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212429419722': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212429550795': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212429747404': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212429944013': array([0., 0., 0., ..., 1., 0., 0.]),
#  '102844212430075086': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212430271695': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212430402768': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212430599377': array([0., 0., 0., ..., 0., 0., 0.]),
#  '102844212430730450': array([0., 0., 0., ..., 1., 1., 1.]),
#  '102844212430927059': array([0., 0., 0., ..., 1., 1., 1.]),
#  '102844212431058132': array([0., 0., 0., ..., 1., 1., 1.]),
#  '102844212431320277': array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %%
import pickle
with open('/home/ubuntu/gangmin/tsvt/video/lolData/exp_data/highlight_label.pickle',"rb") as f:
    label = pickle.load(f)

# %%
for key in label.keys():
    print(len(label[key]))
    frames[key] = frames[key][:len(label[key])]
    print(len(frames[key]))
# Out:
# 2331
# 2331
# 2138
# 2138
# 1823
# 1823
# 1689
# 1689
# 1700
# 1700
# 1777
# 1777
# 1852
# 1852
# 1670
# 1670
# 2819
# 2819
# 2216
# 2216
# 1564
# 1564
# 2069
# 2069
# 2416
# 2416
# 1934
# 1934
# 1654
# 1654
# 1701
# 1701
# 1472
# 1472
# 2343
# 2343
# 1920
# 1920
# 1805
# 1805
# 2464
# 2464
# 1826
# 1826
# 1672
# 1672
# 1745
# 1745
# 2052
# 2052
# 2329
# 2329
# 1473
# 1473
# 1818
# 1818
# 2199
# 2199
# 1427
# 1427
# 2251
# 2251
# 1408
# 1408
# 2630
# 2630
# 2451
# 2451
# 1569
# 1569
# 2335
# 2335
# 1604
# 1604
# 2329
# 2329
# 1564
# 1564
# 1984
# 1984
# 1466
# 1466
# 2267
# 2267
# 1534
# 1534
# 2279
# 2279
# 2526
# 2526
# 2398
# 2398
# 1910
# 1910
# 1797
# 1797
# 2519
# 2519
# 1906
# 1906
# 1982
# 1982
# 2155
# 2155
# 2051
# 2051
# 1981
# 1981
# 2148
# 2148
# 1545
# 1545
# 2158
# 2158
# 1611
# 1611
# 2056
# 2056
# 1860
# 1860
# 1643
# 1643
# 2289
# 2289
# 2125
# 2125
# 1940
# 1940
# 2365
# 2365
# 1358
# 1358
# 1652
# 1652
# 1453
# 1453
# 2083
# 2083
# 1834
# 1834
# 1795
# 1795
# ...

# %%
for key in label.keys():
    # end highlight
    for end in range(len(frames[key])-48,len(frames[key])):
        frames[key][end] = 1

# %%
while len(frames.keys())!=112:
    for key in frames.keys():
        if key not in label.keys():
            frames.pop(key)
            break

# %%
import pickle
with open('/home/ubuntu/gangmin/tsvt/multimodal/data/video_frames4.pickle','wb') as f:
    pickle.dump(frames,f)
with open('/home/ubuntu/gangmin/tsvt/multimodal/label/label.pickle','wb') as f:
    pickle.dump(label,f)

# %%
len(frames.keys())
# Out:
# 112

# %%
train=['102844412722519367',
 '102844212429550795',
 '102844401151219358',
 '102844401154430631',
 '102844412717014335',
 '102844401153971877',
 '102844224148503678',
 '102844412722847048',
 '102844401152857762',
 '102844412707380528',
 '102844212431516886',
 '102844283027925085',
 '102844412716227901',
 '102844412710001974',
 '102844294670878922',
 '102844294670551241',
 '102844283023599703',
 '102844412704496937',
 '102844235751783874',
 '102844401152071328',
 '102844412709674293',
 '102844401153447587',
 '102844224148896895',
 '102844235746868664',
 '102979081290790284',
 '102844283027531868',
 '102844212431975640',
 '102844401155937960',
 '102844212429092040',
 '102844341906649746',
 '102844412706987311',
 '102844412721339716',
 '102844212430402768',
 '102844341905011343',
 '102844235753356742',
 '102844235750997440',
 '102844412709346612',
 '102844412705217835',
 '102844235752963525',
 '102844412712164667',
 '102844412705545516',
 '102844341912220311',
 '102844341907370644',
 '102844235749424575',
 '102844212429419722',
 '102844294669568199',
 '102844212431779031',
 '102844294666422466',
 '102844224146472059',
 '102844212428895431',
 '102844212429747404',
 '102844235748703677',
 '102844224146930812',
 '102844212430730450',
 '102844294674876621',
 '102844341909598870',
 '102844283020453971',
 '102844294670026952',
 '102844412723174729',
 '102844341904683662',
 '102844283025696858',
 '102844235747261881',
 '102844401154168486',
 '102844235748310460',
 '102844412711836986',
 '102844412723567946',
 '102844235749031358',
 '102844294674286796',
 '102844294666881219',
 '102844412716686654']
val=['102844294671796427',
 '102844224145685626',
 '102844412717407552',
 '102844235751390657',
 '102844401156069033',
 '102904869420860038',
 '102910307641576395',
 '102844341905404560',
 '102844341906977427',
 '102844212430075086',
 '102844412711116088',
 '102844401153578660',
 '102844294667405508',
 '102844412706659630']
test=['102844212431058132',
 '102844341902586509',
 '102844401152267937',
 '102844212430927059',
 '102844412708953395',
 '102844212429944013',
 '102844341912679064',
 '102844235753749959',
 '102844341908026005',
 '102844283023206486',
 '102844224147717245',
 '102844412704890154',
 '102844212430599377',
 '102844412711443769',
 '102844235747982779']

# %%
test_video = {}
for key in test:
    test_video[str(key)] = frames[str(key)]

# %% [markdown]
# # TP FP TN FN

# %%
train_video={}
for key in train:
    train_video[str(key)] = frames[str(key)]

# %%
##train

average = [0,0,0,0,0]
for key in train_video.keys():
    TP = len(np.where((train_video[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((train_video[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((train_video[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((train_video[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
        print(key)
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# 102844412722519367
# precision : 0.6038961038961039, recall : 0.8157894736842105, f1 : 0.6940298507462687, accuracy : 0.8811019816336394
# 102844212429550795
# precision : 0.6451612903225806, recall : 0.49504950495049505, f1 : 0.5602240896358545, accuracy : 0.8933423913043478
# 102844401151219358
# precision : 0.6643835616438356, recall : 0.8858447488584474, f1 : 0.7592954990215264, accuracy : 0.9364012409513961
# 102844401154430631
# precision : 0.7014925373134329, recall : 0.8826291079812206, f1 : 0.7817047817047817, accuracy : 0.9364406779661016
# 102844412717014335
# precision : 0.572744014732965, recall : 0.9067055393586005, f1 : 0.7020316027088035, accuracy : 0.8614900314795383
# 102844401153971877
# precision : 0.5127478753541076, recall : 0.9526315789473684, f1 : 0.6666666666666666, accuracy : 0.8981429375351716
# 102844224148503678
# precision : 0.6096718480138169, recall : 0.8694581280788177, f1 : 0.716751269035533, accuracy : 0.8654773384763742
# 102844412722847048
# ...

# %%
##test

average = [0,0,0,0,0]
for key in test_video.keys():
    TP = len(np.where((test_video[key]==1)&(label[key]==1)==True)[0])
    FP = len(np.where((test_video[key]==1)&(label[key]==0)==True)[0])
    TN = len(np.where((test_video[key]==0)&(label[key]==0)==True)[0])
    FN = len(np.where((test_video[key]==0)&(label[key]==1)==True)[0])

    
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN) / (TP+FN+FP+TN)
    
    if precision==0 and recall == 0:
        print('!')
    else:
    
        f1 = (2*precision*recall / (precision + recall))
        print(key)
        print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(precision,recall,f1,accuracy))
        average[0]+= precision
        average[1] += recall
        average[2] += f1
        average[3] += accuracy
        average[4]+=1
# Out:
# 102844212431058132
# precision : 0.5523114355231143, recall : 0.5958005249343832, f1 : 0.5732323232323232, accuracy : 0.8628246753246753
# 102844341902586509
# precision : 0.524390243902439, recall : 0.849802371541502, f1 : 0.6485671191553545, accuracy : 0.8910196445275959
# 102844401152267937
# precision : 0.6093023255813953, recall : 0.9776119402985075, f1 : 0.7507163323782235, accuracy : 0.8859764089121888
# 102844212430927059
# precision : 0.6429587482219061, recall : 0.6848484848484848, f1 : 0.6632428466617755, accuracy : 0.8793058112016828
# 102844412708953395
# precision : 0.6056701030927835, recall : 0.8514492753623188, f1 : 0.7078313253012046, accuracy : 0.9056420233463035
# 102844212429944013
# precision : 0.6029411764705882, recall : 0.8840970350404312, f1 : 0.7169398907103826, accuracy : 0.8734115347018573
# 102844341912679064
# precision : 0.572347266881029, recall : 0.7876106194690266, f1 : 0.6629422718808193, accuracy : 0.906701030927835
# 102844235753749959
# ...

# %%
average
# Out:
# [9.12103001673336,
#  11.52717173119888,
#  10.096366211763886,
#  13.14314718352887,
#  15]

# %%
print('precision : {}, recall : {}, f1 : {}, accuracy : {}'.format(average[0]/average[4],average[1]/average[4],average[2]/average[4],average[3]/average[4]))
# Out:
# precision : 0.608068667782224, recall : 0.7684781154132587, f1 : 0.673091080784259, accuracy : 0.876209812235258
